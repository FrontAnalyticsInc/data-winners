# %% [markdown]
# # Google Search Console GSC API Examples
#
#
# ### Overview
#
# If you are interested in your organic traffic then the Google Search Console is hands down
# one of the richest datasources.
#
# Here are example scripts for connecting to this valuable datasource.
#
#
#
# ### About Me
#
# My name is Alton Alexander. I am a Data Science consultant turned entreprenuer building SaaS tools for SEO.
#
# Find more about my free scripts or ask me any question on twitter: @alton_lex

# %% [markdown]
# # GSC API Examples:

# %%
# load libraries
import requests
import json
from urllib.parse import urlparse

import httplib2
from apiclient import errors
from apiclient.discovery import build

import datetime

from google.oauth2 import service_account
import google.oauth2.credentials
import google.auth.transport.requests

# !pip install pandas
import pandas as pd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/alton/.local/lib/python3.10/site-packages (1.5.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/alton/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/lib/python3/dist-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %% [markdown]
# ## 0) Setup service account
#
# In Google Cloud Console you need to create the following resources:
#
# 1. A project
#
# 2. Enable Access to the GSC API
#
# 3. A service account (make note of the Email for the service account)
#
# 4. OPTIONAL Add rolls to the service account so that it can access additional resources (ie. BigQuery)
#
# 5. Save the Key as JSON for connecting from python
#
#
# In Google Search Console:
#
# 1. add the service account email as a user to each of the properties you want it to access

# %% [markdown]
# ## 1) Connect with Service Account JSON key
#
# Every request to the GSC API must have user authentication.
#
# We use the service account JSON Key we get credentials.

# %%
# local path to the service account key
# service account's email must be added to one or more properties in GSC

#SERVICE_ACCOUNT_FILE = "../gcp-keys/website-analytics-161019-16456165cddc.json"
SERVICE_ACCOUNT_FILE = "./service-account-key.json"

# %%
SCOPES = ['https://www.googleapis.com/auth/webmasters']
credentials = service_account.Credentials.from_service_account_file(
        SERVICE_ACCOUNT_FILE, scopes=SCOPES)

# %%
webmasters_service = build(
    'webmasters',
    'v3',
    credentials=credentials
)

# %%
# test by pulling a list of sites
# reminder to add the service account email to every GSC property as a user


response = webmasters_service.sites().list().execute()
response
# Out:
# {'siteEntry': [{'siteUrl': 'sc-domain:frontanalytics.com',
#    'permissionLevel': 'siteFullUser'}]}

# %%
# Furthermore now we have credentials stored in credentials.token

# preview the token
credentials.token[0:30]+"............"
# Out:
# 'ya29.c.b0AT7lpjCAmdthmSx_9bNWk............'

# %% [markdown]
# ## 1) Pull a list of pages
#
# This pulls a list of all the pages that are showing on Google Search in the last 30 days:

# %%
# define the domain that we are using

# hardcode the domain for the property
#site = "frontanalytics.com"

# or select the first property from the response above
site = response['siteEntry'][0]['siteUrl'].split(":")[1]
site

# %%
# set date for the last 30 days
today = datetime.datetime.today()
startDate = today - datetime.timedelta(days=32)
endDate = today - datetime.timedelta(days=2)

# %%
# by page

# recent
# Set the dates in this format "2022-12-01"
data = {
  "startDate": startDate.strftime("%Y-%m-%d"),
  "endDate": endDate.strftime("%Y-%m-%d"),
  "dimensions": "page"
}
res = requests.post("https://www.googleapis.com/webmasters/v3/sites/"+"sc-domain:"+site+"/searchAnalytics/query?access_token="+credentials.token, json=data)

# %%
# check for valid resonse
if str(res.status_code) != "200":
    print("error with the api response. verify credentials are active.")

j = json.loads(res.text)['rows']
for i in range(len(j)):
    j[i]['url'] = j[i]['keys'][0]

df_pages = pd.DataFrame(j)

df_pages = df_pages.sort_values('impressions',ascending=False)
df_pages

# %% [markdown]
# ## 2) Get all KWs for each page
#
# This pulls every query used for each page:

# %%
# set date for the previous 1 days (day before yesterday)
today = datetime.datetime.today()
startDate = today - datetime.timedelta(days=3)
endDate = today - datetime.timedelta(days=2)

df_all_queries = pd.DataFrame()

# Get all the queries
for index, row in df_pages.iterrows():
    
    # get the url of this page
    page_url = row['url']

    # recent
    data = {
      "startDate": startDate.strftime("%Y-%m-%d"),
      "endDate": endDate.strftime("%Y-%m-%d"),
      "dimensions": ["query","device","country"],
      "dimensionFilterGroups": [
        {
          "groupType": "and",
          "filters": [
            {
              "dimension": "page",
              "operator": "contains",
              "expression": page_url
            }
          ]
        }
      ]
    }
    res = requests.post("https://www.googleapis.com/webmasters/v3/sites/"+"sc-domain:"+site+"/searchAnalytics/query?access_token="+credentials.token, json=data)

    # convert the response to a data frame
    j = json.loads(res.text).get('rows',[])

    if(len(j)):
        df_queries = pd.DataFrame(j)
        df_queries['url'] = page_url
        df_queries['property'] = site
        df_queries['start_date'] = startDate
        df_queries['update_at'] = today

        # By default the keys/dimensions are in a single column, let's split them out into separate columns.
        new_cols = df_queries['keys'].astype(str).str.replace("[","").str.replace("]","")
        new_cols = new_cols.str.split(pat=',',expand=True,n=2)

        # Give the columsn sensible names
        new_cols.columns = ["query","device","country"]

        # Bring back a key from the intial dataframe so we can join
        new_cols['key'] = df_queries['keys']

        # Get rid of quotation marks
        new_cols['query'] = new_cols.apply(lambda row : row['query'].replace("'","").lower(), axis=1)
        
        if 'device' in new_cols:
            new_cols['device'] = new_cols.apply(lambda row : row['device'].replace("'","").lower(), axis=1)
        else:
            new_cols['device'] = None
        if 'country' in new_cols:
            new_cols['country'] = new_cols.apply(lambda row : row['country'].replace("'","").lower(), axis=1)
        else:
            new_cols['country'] = None

        # Join in the new clean columns to our intiial data
        df_queries = pd.concat([df_queries, new_cols], axis=1, join='inner')

        # Drop the key columns
        df_queries = df_queries.drop(["key","keys"],axis=1)

        # save all the queries for this page with all other pages
        df_all_queries = pd.concat([df_all_queries, df_queries])

# %%
# Now you can save df_all_queries for additional analysis
df_all_queries
# Out:
#     clicks  impressions  ctr  position  \
# 0        1            1    1         3
# 1        0            1    0        21
# 2        0            1    0        21
# 3        0            1    0        21
# 4        0            2    0        23
# 5        0            1    0        41
# 6        0            1    0        95
# 7        0            1    0        29
# 8        0            1    0        29
# 9        0            1    0        88
# 10       0            1    0         3
# 11       0            8    0         3
# 12       0            1    0         8
# 13       0            1    0         5
# 14       0            1    0         5
# 15       0            1    0         7
# 16       0            1    0        58
# 17       0            1    0        56
# 18       0            1    0        77
# 19       0            1    0        60
# 0        0            1    0        21
# 1        0            1    0        21
# 2        0            1    0        21
# 3        0            2    0        23
# 4        0            1    0        41
# 0        0            1    0        88
# 1        0            1    0        58
# 2        0            1    0        56
# 3        0            1    0        77
# 4        0            1    0        60
# 0        0            1    0        95
# 1        0            1    0        29
# 2        0            1    0        29
# 0        0            2    0         3
# 0        0            2    0         3
# 0        0            2    0         3
#
#                                                   url            property  \
# 0                         https://frontanalytics.com/  frontanalytics.com
# 1                         https://frontanalytics.com/  frontanalytics.com
# 2                         https://frontanalytics.com/  frontanalytics.com
# 3                         https://frontanalytics.com/  frontanalytics.com
# 4                         https://frontanalytics.com/  frontanalytics.com
# 5                         https://frontanalytics.com/  frontanalytics.com
# 6                         https://frontanalytics.com/  frontanalytics.com
# 7                         https://frontanalytics.com/  frontanalytics.com
# 8                         https://frontanalytics.com/  frontanalytics.com
# 9                         https://frontanalytics.com/  frontanalytics.com
# 10                        https://frontanalytics.com/  frontanalytics.com
# 11                        https://frontanalytics.com/  frontanalytics.com
# 12                        https://frontanalytics.com/  frontanalytics.com
# 13                        https://frontanalytics.com/  frontanalytics.com
# 14                        https://frontanalytics.com/  frontanalytics.com
# 15                        https://frontanalytics.com/  frontanalytics.com
# 16                        https://frontanalytics.com/  frontanalytics.com
# 17                        https://frontanalytics.com/  frontanalytics.com
# 18                        https://frontanalytics.com/  frontanalytics.com
# 19                        https://frontanalytics.com/  frontanalytics.com
# 0      https://frontanalytics.com/advanced-analytics/  frontanalytics.com
# 1      https://frontanalytics.com/advanced-analytics/  frontanalytics.com
# 2      https://frontanalytics.com/advanced-analytics/  frontanalytics.com
# 3      https://frontanalytics.com/advanced-analytics/  frontanalytics.com
# 4      https://frontanalytics.com/advanced-analytics/  frontanalytics.com
# 0   https://frontanalytics.com/system-dynamics-mod...  frontanalytics.com
# 1   https://frontanalytics.com/system-dynamics-mod...  frontanalytics.com
# 2   https://frontanalytics.com/system-dynamics-mod...  frontanalytics.com
# 3   https://frontanalytics.com/system-dynamics-mod...  frontanalytics.com
# 4   https://frontanalytics.com/system-dynamics-mod...  frontanalytics.com
# 0   https://frontanalytics.com/inbound-call-center...  frontanalytics.com
# 1   https://frontanalytics.com/inbound-call-center...  frontanalytics.com
# 2   https://frontanalytics.com/inbound-call-center...  frontanalytics.com
# 0                   https://frontanalytics.com/about/  frontanalytics.com
# 0                 https://frontanalytics.com/contact/  frontanalytics.com
# 0                 https://frontanalytics.com/privacy/  frontanalytics.com
#
#                    start_date                  update_at  \
# 0  2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 1  2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 2  2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 3  2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 4  2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 5  2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 6  2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 7  2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 8  2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 9  2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 10 2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 11 2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 12 2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 13 2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 14 2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 15 2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 16 2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 17 2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 18 2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 19 2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 0  2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 1  2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 2  2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 3  2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 4  2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 0  2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 1  2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 2  2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 3  2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 4  2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 0  2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 1  2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 2  2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 0  2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 0  2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
# 0  2023-01-10 22:11:59.430622 2023-01-13 22:11:59.430622
#
#                                             query    device country
# 0                                 front analytics   desktop     gbr
# 1          advanced analytics generally refers to   desktop     chl
# 2          advanced analytics generally refers to   desktop     col
# 3          advanced analytics generally refers to   desktop     rus
# 4          advanced analytics generally refers to   desktop     usa
# 5                    advanced analytics refers to   desktop     usa
# 6                call center analytics case study    mobile     irl
# 7             call center optimization case study   desktop     mys
# 8             call center optimization case study   desktop     usa
# 9                          define system dynamics   desktop     jpn
# 10                                front analytics   desktop     deu
# 11                                front analytics   desktop     usa
# 12                                     front data   desktop     fra
# 13                             in front analytics   desktop     fra
# 14                             in front analytics   desktop     idn
# 15                             in front analytics    mobile     ita
# 16  what can system dynamics modeling be used for   desktop     aut
# 17  what can system dynamics modeling be used for   desktop     esp
# 18               what is system dynamics modeling   desktop     can
# 19               what is system dynamics modeling   desktop     hkg
# 0          advanced analytics generally refers to   desktop     chl
# 1          advanced analytics generally refers to   desktop     col
# 2          advanced analytics generally refers to   desktop     rus
# 3          advanced analytics generally refers to   desktop     usa
# 4                    advanced analytics refers to   desktop     usa
# 0                          define system dynamics   desktop     jpn
# 1   what can system dynamics modeling be used for   desktop     aut
# 2   what can system dynamics modeling be used for   desktop     esp
# 3                what is system dynamics modeling   desktop     can
# 4                what is system dynamics modeling   desktop     hkg
# 0                call center analytics case study    mobile     irl
# 1             call center optimization case study   desktop     mys
# 2             call center optimization case study   desktop     usa
# 0                                 front analytics   desktop     usa
# 0                                 front analytics   desktop     usa
# 0                                 front analytics   desktop     usa
