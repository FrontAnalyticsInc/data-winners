# %% [markdown]
# # Scrape top Google Results

# %% [markdown]
# ### Overview
#
# If you are interested in search traffic (paid or organic) then the it is important to monitor SERPs.
#
# Here is data you can get using just requests!
#
#
# ### About Me
#
# My name is Alton Alexander. I am a Data Science consultant turned entreprenuer building SaaS tools for SEO.
#
# Find more about my free scripts or ask me any questions
#
# Follow me for more data and tutorials
#
# - twitter: https://twitter.com/alton_lex @alton_lex
#
# - linkedin: https://www.linkedin.com/in/altonalexander/
#
#
# ### About Data Winners
#
# Join the conversation:
#
# - private Discord community
#
# - Video tutorials
#
# - Feedback and support on this and other scripts
#
# Join now: https://datawinners.gumroad.com/l/data-analytics-for-seo

# %% [markdown]
# ###  Motivation:
#
# scrape a SERP result for any given search query and extract the basic HTML tags like page titles, H1s, H2s-H6s, and so on
#
# not interested on the entire domain but a particular page/post
#
# this would be to improve the blog article outline process
#
# so I can see how the top ranking results for any given query is structuring their content

# %% [markdown]
# ##  Step 1) Get the SERP page

# %%
# get the libraries
# !pip install googlesearch-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: googlesearch-python in /home/alton/.local/lib/python3.10/site-packages (1.1.0)
# Requirement already satisfied: beautifulsoup4==4.9.3 in /home/alton/.local/lib/python3.10/site-packages (from googlesearch-python) (4.9.3)
# Requirement already satisfied: requests==2.25.1 in /usr/lib/python3/dist-packages (from googlesearch-python) (2.25.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/lib/python3/dist-packages (from beautifulsoup4==4.9.3->googlesearch-python) (2.3.1)
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import requests
from googlesearch import search
from bs4 import BeautifulSoup
search("Google")
# Out:
# <generator object search at 0x7f2ca26228f0>

# %%
query = "python for seo"
results_generator = search(query, num_results=10, lang="en")

# %%
# loop over the generator and save to a list
results = []

for link in list(results_generator):
    print(link)
    results.append(link)
# Out:
# https://www.jcchouinard.com/python-for-seo/
# https://www.python.org/success-stories/python-seo-link-analyzer/
# https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/
# https://www.danielherediamejias.com/python-scripts-seo/
# https://www.rankranger.com/blog/python-for-seo
# https://importsem.com/
# https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site
# https://github.com/sethblack/python-seo-analyzer
# https://www.seoradar.com/how-to-use-python-seo/
# https://rockcontent.com/blog/python-for-seo/

# %% [markdown]
# # Step 2) A custom function to extract info from each link
#
# Input a link
#
# Get out a list of sections

# %%
def parse_page_to_sections_list( link ):
    '''
    
    Simple function to download the raw html of a link
    parses contents into an array of dictionaries
    
    '''
    page = requests.get(link)
    soup = BeautifulSoup(page.text, "lxml")

    title = soup.find("title").text

    headers = ['h1', 'h2', 'h3', 'h4', 'h5']

    df_json = []

    for header in headers:
        sections = soup.find_all(header)

        order = 0
        for section in sections:
            tmp = {
                "url": link,
                "page_title": title,
                "header": header,
                "order": order,
                "title": section.text
            }
            df_json.append( tmp )
            order = order +1

    return df_json

# %%
# test our function

link = "https://www.jcchouinard.com/python-for-seo/"
parse_page_to_sections_list( link )
# Out:
# [{'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h1',
#   'order': 0,
#   'title': 'Python for SEO: Complete Guide (in 8 Chapters)'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h2',
#   'order': 0,
#   'title': 'Subscribe to my Newsletter'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h2',
#   'order': 1,
#   'title': 'Chapter 1: Python Basics'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h2',
#   'order': 2,
#   'title': 'Chapter 2: Technical SEO Challenges'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h2',
#   'order': 3,
#   'title': 'Chapter 3: Automation With Python'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h2',
#   'order': 4,
#   'title': 'Chapter 4: Use APIs With Python'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h2',
#   'order': 5,
#   'title': 'Chapter 5: Social Media Automation'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h2',
#   'order': 6,
#   'title': 'Chapter 6: SEO Split Testing'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h2',
#   'order': 7,
#   'title': 'Chapter 7: Machine Learning'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h2',
#   'order': 8,
#   'title': 'Chapter 8: Web Development'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h2',
#   'order': 9,
#   'title': 'Other Useful Guides For SEO'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h2',
#   'order': 10,
#   'title': 'Python SEO FAQs'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h2',
#   'order': 11,
#   'title': 'About Python Programming Language'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h2',
#   'order': 12,
#   'title': 'Post navigation'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h3',
#   'order': 0,
#   'title': '📙How to Learn Python for SEO?'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h3',
#   'order': 1,
#   'title': '🐍How to get started with Python?'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h3',
#   'order': 2,
#   'title': '⭐How to Automate SEO with Python?'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h3',
#   'order': 3,
#   'title': '❤️What are the Best Python SEO APIs?'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h3',
#   'order': 4,
#   'title': 'Related posts:'}]

# %% [markdown]
# # Step 3: Parse each page in For loop

# %%
df_master_list = []

for link in results:
    print(link)
    df_json = parse_page_to_sections_list(link)
    df_master_list.extend(df_json)

df_master_list
# Out:
# https://www.jcchouinard.com/python-for-seo/
# https://www.python.org/success-stories/python-seo-link-analyzer/
# https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/
# https://www.danielherediamejias.com/python-scripts-seo/
# https://www.rankranger.com/blog/python-for-seo
# https://importsem.com/
# https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site
# https://github.com/sethblack/python-seo-analyzer
# https://www.seoradar.com/how-to-use-python-seo/
# https://rockcontent.com/blog/python-for-seo/
# [{'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h1',
#   'order': 0,
#   'title': 'Python for SEO: Complete Guide (in 8 Chapters)'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h2',
#   'order': 0,
#   'title': 'Subscribe to my Newsletter'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h2',
#   'order': 1,
#   'title': 'Chapter 1: Python Basics'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h2',
#   'order': 2,
#   'title': 'Chapter 2: Technical SEO Challenges'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h2',
#   'order': 3,
#   'title': 'Chapter 3: Automation With Python'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h2',
#   'order': 4,
#   'title': 'Chapter 4: Use APIs With Python'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h2',
#   'order': 5,
#   'title': 'Chapter 5: Social Media Automation'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h2',
#   'order': 6,
#   'title': 'Chapter 6: SEO Split Testing'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h2',
#   'order': 7,
#   'title': 'Chapter 7: Machine Learning'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h2',
#   'order': 8,
#   'title': 'Chapter 8: Web Development'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h2',
#   'order': 9,
#   'title': 'Other Useful Guides For SEO'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h2',
#   'order': 10,
#   'title': 'Python SEO FAQs'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h2',
#   'order': 11,
#   'title': 'About Python Programming Language'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h2',
#   'order': 12,
#   'title': 'Post navigation'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h3',
#   'order': 0,
#   'title': '📙How to Learn Python for SEO?'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h3',
#   'order': 1,
#   'title': '🐍How to get started with Python?'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h3',
#   'order': 2,
#   'title': '⭐How to Automate SEO with Python?'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h3',
#   'order': 3,
#   'title': '❤️What are the Best Python SEO APIs?'},
#  {'url': 'https://www.jcchouinard.com/python-for-seo/',
#   'page_title': 'Python for SEO: Complete Guide (in 8 Chapters) - JC Chouinard',
#   'header': 'h3',
#   'order': 4,
#   'title': 'Related posts:'},
#  {'url': 'https://www.python.org/success-stories/python-seo-link-analyzer/',
#   'page_title': 'Using Python scripts to analyse SEO and broken links on your site | Our Success Stories | Python.org',
#   'header': 'h1',
#   'order': 0,
#   'title': '\n\n'},
#  {'url': 'https://www.python.org/success-stories/python-seo-link-analyzer/',
#   'page_title': 'Using Python scripts to analyse SEO and broken links on your site | Our Success Stories | Python.org',
#   'header': 'h1',
#   'order': 1,
#   'title': 'Using Python scripts to analyse SEO and broken links on your site'},
#  {'url': 'https://www.python.org/success-stories/python-seo-link-analyzer/',
#   'page_title': 'Using Python scripts to analyse SEO and broken links on your site | Our Success Stories | Python.org',
#   'header': 'h2',
#   'order': 0,
#   'title': 'Python SEO analyzer'},
#  {'url': 'https://www.python.org/success-stories/python-seo-link-analyzer/',
#   'page_title': 'Using Python scripts to analyse SEO and broken links on your site | Our Success Stories | Python.org',
#   'header': 'h2',
#   'order': 1,
#   'title': 'Conclusion'},
#  {'url': 'https://www.python.org/success-stories/python-seo-link-analyzer/',
#   'page_title': 'Using Python scripts to analyse SEO and broken links on your site | Our Success Stories | Python.org',
#   'header': 'h3',
#   'order': 0,
#   'title': 'Using the SEO analyzer'},
#  {'url': 'https://www.python.org/success-stories/python-seo-link-analyzer/',
#   'page_title': 'Using Python scripts to analyse SEO and broken links on your site | Our Success Stories | Python.org',
#   'header': 'h3',
#   'order': 1,
#   'title': 'Link status analyser'},
#  {'url': 'https://www.python.org/success-stories/python-seo-link-analyzer/',
#   'page_title': 'Using Python scripts to analyse SEO and broken links on your site | Our Success Stories | Python.org',
#   'header': 'h4',
#   'order': 0,
#   'title': 'Using the link status analyser'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h1',
#   'order': 0,
#   'title': '\n            An Introduction To Python & Machine Learning For Technical SEO        '},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h2',
#   'order': 0,
#   'title': 'What Is Python?'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h2',
#   'order': 1,
#   'title': 'How To Learn Python'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h2',
#   'order': 2,
#   'title': 'Why Python Is Popular With SEOs'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h2',
#   'order': 3,
#   'title': 'Example Ways To Use Python'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h2',
#   'order': 4,
#   'title': 'Powering Machine Learning'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h2',
#   'order': 5,
#   'title': 'Conclusion'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h2',
#   'order': 6,
#   'title': 'Python Contributions From The SEO Industry'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h2',
#   'order': 7,
#   'title': '\n\n                    Ruth Everett                \n'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h2',
#   'order': 8,
#   'title': '\n\n                                Digital Marketing In 2023: 600 Marketing Agencies Share Expert Insights                            \n'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h2',
#   'order': 9,
#   'title': '\n\n                                How To Supercharge Your Keyword Research With Powerful Topic Clustering                            \n'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h3',
#   'order': 0,
#   'title': 'SEO Trends 2023'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h3',
#   'order': 1,
#   'title': 'SEO Trends 2023'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h3',
#   'order': 2,
#   'title': 'PPC Trends 2023'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h3',
#   'order': 3,
#   'title': 'Content Marketing For Finance'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h3',
#   'order': 4,
#   'title': 'How to Advertise on Facebook: A Beginner’s Guide'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h3',
#   'order': 5,
#   'title': 'UX & SEO Guide'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h3',
#   'order': 6,
#   'title': '\n\n                        Ruth Everett                    \n'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h3',
#   'order': 7,
#   'title': '\nRuth Everett\n'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h3',
#   'order': 8,
#   'title': 'How To Run Python'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h3',
#   'order': 9,
#   'title': 'Python Libraries'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h3',
#   'order': 10,
#   'title': 'The Benefits Of Automating With Python'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h3',
#   'order': 11,
#   'title': 'How To Add Python To Your SEO Workflow'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h3',
#   'order': 12,
#   'title': 'Redirect Relevancy'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h3',
#   'order': 13,
#   'title': 'Internal Link Analysis'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h3',
#   'order': 14,
#   'title': 'Image Captioning With Pythia'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h3',
#   'order': 15,
#   'title': 'APIs'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h3',
#   'order': 16,
#   'title': 'Other Possibilities'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h3',
#   'order': 17,
#   'title': 'What Is Machine Learning?'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h3',
#   'order': 18,
#   'title': 'Python & Machine Learning'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h3',
#   'order': 19,
#   'title': 'Real-World Machine Learning Examples'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h3',
#   'order': 20,
#   'title': 'SEO Possibilities With Machine Learning'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h3',
#   'order': 21,
#   'title': 'Predictive Prefetching'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h3',
#   'order': 22,
#   'title': 'Internal Linking'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h3',
#   'order': 23,
#   'title': 'Content Quality'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h3',
#   'order': 24,
#   'title': 'User Experience'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h3',
#   'order': 25,
#   'title': 'Subscribe to SEJ'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h4',
#   'order': 0,
#   'title': '\n\n        \t\t\t\t\tVector Search: Optimizing For The Human Mind With Machine Learning                            \n'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h4',
#   'order': 1,
#   'title': '\n\n        \t\t\t\t\t8 Machine Learning Examples From Brands To Inspire Digital Marketers                            \n'},
#  {'url': 'https://www.searchenginejournal.com/python-machine-learning-technical-seo/430000/',
#   'page_title': 'An Introduction To Python & Machine Learning For Technical SEO',
#   'header': 'h4',
#   'order': 2,
#   'title': '\n\n        \t\t\t\t\tHow Does Machine Learning Work in Paid Search Marketing?                            \n'},
#  {'url': 'https://www.danielherediamejias.com/python-scripts-seo/',
#   'page_title': 'Python Scripts for SEOs - Daniel Heredia',
#   'header': 'h1',
#   'order': 0,
#   'title': 'Python Scripts for SEOs'},
#  {'url': 'https://www.danielherediamejias.com/python-scripts-seo/',
#   'page_title': 'Python Scripts for SEOs - Daniel Heredia',
#   'header': 'h2',
#   'order': 0,
#   'title': 'Posts navigation'},
#  {'url': 'https://www.danielherediamejias.com/python-scripts-seo/',
#   'page_title': 'Python Scripts for SEOs - Daniel Heredia',
#   'header': 'h2',
#   'order': 1,
#   'title': 'Most popular posts'},
#  {'url': 'https://www.danielherediamejias.com/python-scripts-seo/',
#   'page_title': 'Python Scripts for SEOs - Daniel Heredia',
#   'header': 'h2',
#   'order': 2,
#   'title': 'Follow me!'},
#  {'url': 'https://www.danielherediamejias.com/python-scripts-seo/',
#   'page_title': 'Python Scripts for SEOs - Daniel Heredia',
#   'header': 'h2',
#   'order': 3,
#   'title': ' JC Chouinard'},
#  {'url': 'https://www.danielherediamejias.com/python-scripts-seo/',
#   'page_title': 'Python Scripts for SEOs - Daniel Heredia',
#   'header': 'h2',
#   'order': 4,
#   'title': ' Python SEO | importSEM'},
#  {'url': 'https://www.danielherediamejias.com/python-scripts-seo/',
#   'page_title': 'Python Scripts for SEOs - Daniel Heredia',
#   'header': 'h3',
#   'order': 0,
#   'title': 'Find your main relevant words with TF IDF and Python'},
#  {'url': 'https://www.danielherediamejias.com/python-scripts-seo/',
#   'page_title': 'Python Scripts for SEOs - Daniel Heredia',
#   'header': 'h3',
#   'order': 1,
#   'title': 'Using MOZ API with Python'},
#  {'url': 'https://www.danielherediamejias.com/python-scripts-seo/',
#   'page_title': 'Python Scripts for SEOs - Daniel Heredia',
#   'header': 'h3',
#   'order': 2,
#   'title': 'Using Cloudflare Analytics API with Python'},
#  {'url': 'https://www.danielherediamejias.com/python-scripts-seo/',
#   'page_title': 'Python Scripts for SEOs - Daniel Heredia',
#   'header': 'h3',
#   'order': 3,
#   'title': 'Extracting keywords ideas with Python and Keyword Planner API segmented by language'},
#  {'url': 'https://www.danielherediamejias.com/python-scripts-seo/',
#   'page_title': 'Python Scripts for SEOs - Daniel Heredia',
#   'header': 'h3',
#   'order': 4,
#   'title': 'Checking metatitles rewrites with Python and Oxylab’s API'},
#  {'url': 'https://www.danielherediamejias.com/python-scripts-seo/',
#   'page_title': 'Python Scripts for SEOs - Daniel Heredia',
#   'header': 'h3',
#   'order': 5,
#   'title': 'Pruning with Python and htaccess for SEO'},
#  {'url': 'https://www.danielherediamejias.com/python-scripts-seo/',
#   'page_title': 'Python Scripts for SEOs - Daniel Heredia',
#   'header': 'h3',
#   'order': 6,
#   'title': 'Google Alerts and Outreach with Python'},
#  {'url': 'https://www.danielherediamejias.com/python-scripts-seo/',
#   'page_title': 'Python Scripts for SEOs - Daniel Heredia',
#   'header': 'h3',
#   'order': 7,
#   'title': 'On-page optimization with Python for SEO'},
#  {'url': 'https://www.danielherediamejias.com/python-scripts-seo/',
#   'page_title': 'Python Scripts for SEOs - Daniel Heredia',
#   'header': 'h3',
#   'order': 8,
#   'title': 'Guide to SEO on-page scraping with Python'},
#  {'url': 'https://www.danielherediamejias.com/python-scripts-seo/',
#   'page_title': 'Python Scripts for SEOs - Daniel Heredia',
#   'header': 'h3',
#   'order': 9,
#   'title': 'Scraping the Google SERPs with Python and Oxylabs’ API'},
#  {'url': 'https://www.danielherediamejias.com/python-scripts-seo/',
#   'page_title': 'Python Scripts for SEOs - Daniel Heredia',
#   'header': 'h3',
#   'order': 10,
#   'title': 'Doing a competitors analysis with Wappalyzer API and Python'},
#  {'url': 'https://www.danielherediamejias.com/python-scripts-seo/',
#   'page_title': 'Python Scripts for SEOs - Daniel Heredia',
#   'header': 'h3',
#   'order': 11,
#   'title': 'Generating keyword ideas with Python and Keyword Planner from Google Ads API'},
#  {'url': 'https://www.danielherediamejias.com/python-scripts-seo/',
#   'page_title': 'Python Scripts for SEOs - Daniel Heredia',
#   'header': 'h3',
#   'order': 12,
#   'title': 'Page to page redirects with Python and htaccess'},
#  {'url': 'https://www.danielherediamejias.com/python-scripts-seo/',
#   'page_title': 'Python Scripts for SEOs - Daniel Heredia',
#   'header': 'h3',
#   'order': 13,
#   'title': 'Finding inlink opportunities with Python for SEO'},
#  {'url': 'https://www.danielherediamejias.com/python-scripts-seo/',
#   'page_title': 'Python Scripts for SEOs - Daniel Heredia',
#   'header': 'h3',
#   'order': 14,
#   'title': 'Using Copyscape API with Python'},
#  {'url': 'https://www.danielherediamejias.com/python-scripts-seo/',
#   'page_title': 'Python Scripts for SEOs - Daniel Heredia',
#   'header': 'h3',
#   'order': 15,
#   'title': 'Creating a disavow file with Python and Semrush'},
#  {'url': 'https://www.danielherediamejias.com/python-scripts-seo/',
#   'page_title': 'Python Scripts for SEOs - Daniel Heredia',
#   'header': 'h3',
#   'order': 16,
#   'title': 'Using Google Analytics API with Python to create alerts'},
#  {'url': 'https://www.danielherediamejias.com/python-scripts-seo/',
#   'page_title': 'Python Scripts for SEOs - Daniel Heredia',
#   'header': 'h3',
#   'order': 17,
#   'title': 'Scraping Google Play Store with Python and Selenium'},
#  {'url': 'https://www.danielherediamejias.com/python-scripts-seo/',
#   'page_title': 'Python Scripts for SEOs - Daniel Heredia',
#   'header': 'h3',
#   'order': 18,
#   'title': 'Using Wikipedia API with Python for SEO'},
#  {'url': 'https://www.danielherediamejias.com/python-scripts-seo/',
#   'page_title': 'Python Scripts for SEOs - Daniel Heredia',
#   'header': 'h3',
#   'order': 19,
#   'title': 'SEO Internal Linking Analysis with Python and Networkx'},
#  {'url': 'https://www.danielherediamejias.com/python-scripts-seo/',
#   'page_title': 'Python Scripts for SEOs - Daniel Heredia',
#   'header': 'h4',
#   'order': 0,
#   'title': 'Let the Python snake bite you with my newsletter! '},
#  {'url': 'https://www.danielherediamejias.com/python-scripts-seo/',
#   'page_title': 'Python Scripts for SEOs - Daniel Heredia',
#   'header': 'h4',
#   'order': 1,
#   'title': 'What about having a beer or a coffee?'},
#  {'url': 'https://www.rankranger.com/blog/python-for-seo',
#   'page_title': 'Learn Python for Better SEO: Here’s How',
#   'header': 'h1',
#   'order': 0,
#   'title': 'Learn Python for Better SEO: Here’s How'},
#  {'url': 'https://www.rankranger.com/blog/python-for-seo',
#   'page_title': 'Learn Python for Better SEO: Here’s How',
#   'header': 'h2',
#   'order': 0,
#   'title': 'Python: The Basics\xa0'},
#  {'url': 'https://www.rankranger.com/blog/python-for-seo',
#   'page_title': 'Learn Python for Better SEO: Here’s How',
#   'header': 'h2',
#   'order': 1,
#   'title': 'Why Learn Python for SEO?\xa0'},
#  {'url': 'https://www.rankranger.com/blog/python-for-seo',
#   'page_title': 'Learn Python for Better SEO: Here’s How',
#   'header': 'h2',
#   'order': 2,
#   'title': 'How to Learn Python for SEO\xa0'},
#  {'url': 'https://www.rankranger.com/blog/python-for-seo',
#   'page_title': 'Learn Python for Better SEO: Here’s How',
#   'header': 'h2',
#   'order': 3,
#   'title': 'How to Get Started with SEO and Python\xa0'},
#  {'url': 'https://www.rankranger.com/blog/python-for-seo',
#   'page_title': 'Learn Python for Better SEO: Here’s How',
#   'header': 'h2',
#   'order': 4,
#   'title': 'Which Tool to Use for Running the Python Code?\xa0'},
#  {'url': 'https://www.rankranger.com/blog/python-for-seo',
#   'page_title': 'Learn Python for Better SEO: Here’s How',
#   'header': 'h2',
#   'order': 5,
#   'title': 'Best Setup for Python Installation\xa0'},
#  {'url': 'https://www.rankranger.com/blog/python-for-seo',
#   'page_title': 'Learn Python for Better SEO: Here’s How',
#   'header': 'h2',
#   'order': 6,
#   'title': 'SEO Tasks You Can Do with Python\xa0'},
#  {'url': 'https://www.rankranger.com/blog/python-for-seo',
#   'page_title': 'Learn Python for Better SEO: Here’s How',
#   'header': 'h2',
#   'order': 7,
#   'title': 'Four Python Tools for Every Developer\xa0'},
#  {'url': 'https://www.rankranger.com/blog/python-for-seo',
#   'page_title': 'Learn Python for Better SEO: Here’s How',
#   'header': 'h2',
#   'order': 8,
#   'title': 'Learn Python From the Best\n'},
#  {'url': 'https://www.rankranger.com/blog/python-for-seo',
#   'page_title': 'Learn Python for Better SEO: Here’s How',
#   'header': 'h3',
#   'order': 0,
#   'title': 'JR Oakes\xa0'},
#  {'url': 'https://www.rankranger.com/blog/python-for-seo',
#   'page_title': 'Learn Python for Better SEO: Here’s How',
#   'header': 'h3',
#   'order': 1,
#   'title': 'Elias Dabbas\xa0'},
#  {'url': 'https://www.rankranger.com/blog/python-for-seo',
#   'page_title': 'Learn Python for Better SEO: Here’s How',
#   'header': 'h3',
#   'order': 2,
#   'title': 'Seth Black\xa0'},
#  {'url': 'https://www.rankranger.com/blog/python-for-seo',
#   'page_title': 'Learn Python for Better SEO: Here’s How',
#   'header': 'h3',
#   'order': 3,
#   'title': 'What is Anaconda?\xa0'},
#  {'url': 'https://www.rankranger.com/blog/python-for-seo',
#   'page_title': 'Learn Python for Better SEO: Here’s How',
#   'header': 'h3',
#   'order': 4,
#   'title': 'Scikit-Learn\xa0'},
#  {'url': 'https://www.rankranger.com/blog/python-for-seo',
#   'page_title': 'Learn Python for Better SEO: Here’s How',
#   'header': 'h3',
#   'order': 5,
#   'title': 'Keras\n\n'},
#  {'url': 'https://www.rankranger.com/blog/python-for-seo',
#   'page_title': 'Learn Python for Better SEO: Here’s How',
#   'header': 'h3',
#   'order': 6,
#   'title': 'Theano\xa0'},
#  {'url': 'https://www.rankranger.com/blog/python-for-seo',
#   'page_title': 'Learn Python for Better SEO: Here’s How',
#   'header': 'h3',
#   'order': 7,
#   'title': 'SciPy\xa0'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h1',
#   'order': 0,
#   'title': '\nAdvanced Python SEO Scripts for Next Level Results '},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 0,
#   'title': 'Build and Run Python Scripts on the Fly With GPT-3'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 1,
#   'title': 'Compare Keyword SERP Similarity in Bulk with Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 2,
#   'title': 'Analyze SERP Backlink Profiles in Bulk for SEO Using Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 3,
#   'title': 'Detect Generic Anchor Text in Links for SEO using Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 4,
#   'title': 'Detect Text in Images in Bulk With Tesseract Using Python for SEO'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 5,
#   'title': 'Create a Topical Internal Link Graph for SEO with NetworkX and Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 6,
#   'title': 'Evaluate Sentiment Analysis in Bulk with spaCy and Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 7,
#   'title': 'Discover Interlinking Opportunities Using K-Means and Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 8,
#   'title': 'Classify Anchor Text N-Grams for Interlinking Insights with Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 9,
#   'title': 'Webpage Word Sense Disambiguation for SEO Using Python and NLTK'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 10,
#   'title': 'Calculate GSC CTR Stats By Position Using Python for SEO'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 11,
#   'title': 'Use Python and Google Trends to Forecast Your Top GSC Keywords'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 12,
#   'title': 'Use Machine Learning and Python for Easy Text Classification'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 13,
#   'title': 'Detect Google SERP Title and Snippet Rewrites with Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 14,
#   'title': 'Use Python to Create a GSC to BigQuery Pipeline'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 15,
#   'title': 'Overlay GSC Data with Google Algo Updates Using Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 16,
#   'title': 'Build an N-Gram Text Analyzer for SEO using Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 17,
#   'title': 'Bulk IP Filter for Google Analytics Using Python and RegEx'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 18,
#   'title': 'Compare Wikipedia Search Data with Google Trends with Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 19,
#   'title': 'Measure Causal Impact from GSC Data Using Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 20,
#   'title': 'Competitive SEO URL Analysis with Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 21,
#   'title': 'Use Python to Label Query Intent, Entities and Keyword Count'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 22,
#   'title': 'Generate a 404 Redirect List for SEO with Polyfuzz Using Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 23,
#   'title': 'Greg Bernhardt Joins Webinar on How to Perform a Content Audit'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 24,
#   'title': 'Analyze Words Using WordsAPI App and Python for SEO'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 25,
#   'title': 'Scraping YouTube Video Pages for SEO with Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 26,
#   'title': 'Create a Simple Sitemap Generator App for SEO Using Python and Streamlit'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 27,
#   'title': 'Automatically Find SEO Interlinking Opportunities with Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 28,
#   'title': 'SEO Data Blending with Python for Beginners'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 29,
#   'title': 'Is Python SEO Right For You? Practical Python Advice and FAQ'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 30,
#   'title': 'Crawl and Optimize All Website Images With Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 31,
#   'title': 'Automate Image Compression with Python over FTP'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 32,
#   'title': 'Getting Started with Google Cloud Functions and Google Scheduler'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 33,
#   'title': 'Update a Google Sheet with Semrush Position Tracking API Using Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 34,
#   'title': 'Create a Custom Twitter Tweet Alert System with Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 35,
#   'title': 'Find Search Volume Ceiling for Keyword Categories Using Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 36,
#   'title': 'Analyze Crawled PDF Text Using Python for SEO'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 37,
#   'title': 'Hamlet Batista Ranksense Webinar: Data Blending with Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 38,
#   'title': 'Use Python and Brightlocal API to Grab Your Keyword Rankings'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 39,
#   'title': 'How SEOs Can Use Python to Automate Lighthouse Reports'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 40,
#   'title': 'Using Google’s Mobile Friendly Test Tool API with Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 41,
#   'title': 'Detect Web Page Technologies with BuiltWith API and Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 42,
#   'title': 'Use Google NLP to Compare Two Web Page’s Entities Using Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 43,
#   'title': 'Getting Started with Google NLP API Using Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 44,
#   'title': 'Use Python to Scrape Technical Info for Domains'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 45,
#   'title': 'Website Uptime Monitor With LEDs and LCD Screen Using Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 46,
#   'title': 'SEO Guide to Creating a Website Uptime Monitor Using Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 47,
#   'title': 'Use Python Difflib to Detect and Display Robots.txt Changes'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 48,
#   'title': 'SEOs Can Retrieve the Google Cache Date for URLs Using Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 49,
#   'title': 'Extract Google Suggestions API Data for SEO Insights with Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 50,
#   'title': 'Find Keyword Opportunities with Google Trends, Python and Ahrefs'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 51,
#   'title': 'Submit a WordPress Gravity Form via API with Python'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 52,
#   'title': 'Use Python and Chrome to Take Webpage Screenshots'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 53,
#   'title': 'How to Get Cached Pages From Wayback Machine API'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 54,
#   'title': 'External Python SEO Tutorials'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 55,
#   'title': 'Follow Me'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 56,
#   'title': 'Categories'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 57,
#   'title': 'Recent Python SEO Tutorials'},
#  {'url': 'https://importsem.com/',
#   'page_title': 'Python SEO Scripts for Analysis and Automation - importSEM',
#   'header': 'h2',
#   'order': 58,
#   'title': 'Friends'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h1',
#   'order': 0,
#   'title': '19 Python SEO projects that will improve your site'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h2',
#   'order': 0,
#   'title': 'Using Python for SEO is really catching on. There are loads of ways you can use Python SEO projects to improve your work. Here are 19 of the best.'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h3',
#   'order': 0,
#   'title': '1. Automatically generate meta descriptions using AI'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h3',
#   'order': 1,
#   'title': '2. Identify SEO keywords'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h3',
#   'order': 2,
#   'title': '3. Optimise your content for Extractive Question Answering'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h3',
#   'order': 3,
#   'title': '4. Identify near-duplicate content'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h3',
#   'order': 4,
#   'title': '5. Identify keyword cannibalisation'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h3',
#   'order': 5,
#   'title': '6. Analyse non-ranking pages and index bloat'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h3',
#   'order': 6,
#   'title': '7. Identify search traffic trends'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h3',
#   'order': 7,
#   'title': '8. Bulk audit a site’s Core Web Vitals'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h3',
#   'order': 8,
#   'title': '9. Identify internal and external links'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h3',
#   'order': 9,
#   'title': '10. Access Google Analytics and Google Search Console data'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h3',
#   'order': 10,
#   'title': '11. Crawl a site for 404 errors and 301 redirect chains'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h3',
#   'order': 11,
#   'title': '12. Detect anomalies in Google Search Console data'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h3',
#   'order': 12,
#   'title': '13. Generate automated PDF reports'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h3',
#   'order': 13,
#   'title': '14. Machine translate your content'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h3',
#   'order': 14,
#   'title': '15. Build a web site scraper'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h3',
#   'order': 15,
#   'title': '16. Scrape schema.org and OpenGraph metadata'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h3',
#   'order': 16,
#   'title': '17. Scrape and analyse XML sitemaps'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h3',
#   'order': 17,
#   'title': '18. Analyse robots.txt files'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h3',
#   'order': 18,
#   'title': '19. Scrape Google search results'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h3',
#   'order': 19,
#   'title': 'Other posts you might like'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h3',
#   'order': 20,
#   'title': '\nHow to use Pandas from_dict() to create a dataframe\n'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h3',
#   'order': 21,
#   'title': '\nHow to round values in Pandas using round()\n'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h3',
#   'order': 22,
#   'title': '\nHow to get a list of national holiday dates in Python\n'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h3',
#   'order': 23,
#   'title': 'Get the newsletter'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h3',
#   'order': 24,
#   'title': 'Categories'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h3',
#   'order': 25,
#   'title': 'Site'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h3',
#   'order': 26,
#   'title': 'The Practical Data Science blog'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h4',
#   'order': 0,
#   'title': '\nA quick guide to Learning to Rank models\n'},
#  {'url': 'https://practicaldatascience.co.uk/data-science/19-python-seo-projects-that-will-improve-your-site',
#   'page_title': '19 Python SEO projects that will improve your site',
#   'header': 'h4',
#   'order': 1,
#   'title': '\n15 ways you can use data science to boost ecommerce performance\n'},
# ...
#   'header': 'h1',
#   'order': 2,
#   'title': 'Python SEO Analyzer'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h2',
#   'order': 0,
#   'title': 'Latest commit'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h2',
#   'order': 1,
#   'title': 'Git stats'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h2',
#   'order': 2,
#   'title': 'Files'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h2',
#   'order': 3,
#   'title': '\nREADME.md\n'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h2',
#   'order': 4,
#   'title': 'Installation'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h2',
#   'order': 5,
#   'title': 'Command-line Usage'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h2',
#   'order': 6,
#   'title': 'API'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h2',
#   'order': 7,
#   'title': 'Notes'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h2',
#   'order': 8,
#   'title': 'About'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h2',
#   'order': 9,
#   'title': '\n\n    Releases\n      10\n'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h2',
#   'order': 10,
#   'title': '\n\n    Packages 0\n'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h2',
#   'order': 11,
#   'title': '\n\n        Used by 270\n '},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h2',
#   'order': 12,
#   'title': '\n\n    Contributors 17\n'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h2',
#   'order': 13,
#   'title': 'Languages'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h2',
#   'order': 14,
#   'title': 'Footer'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h3',
#   'order': 0,
#   'title': 'License'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h3',
#   'order': 1,
#   'title': 'PIP'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h3',
#   'order': 2,
#   'title': 'Docker'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h3',
#   'order': 3,
#   'title': 'Topics'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h3',
#   'order': 4,
#   'title': 'Resources'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h3',
#   'order': 5,
#   'title': 'License'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h3',
#   'order': 6,
#   'title': 'Code of conduct'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h3',
#   'order': 7,
#   'title': 'Stars'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h3',
#   'order': 8,
#   'title': 'Watchers'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h3',
#   'order': 9,
#   'title': 'Forks'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h3',
#   'order': 10,
#   'title': 'Footer navigation'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h4',
#   'order': 0,
#   'title': 'Sign In Required'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h4',
#   'order': 1,
#   'title': 'Launching GitHub Desktop'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h4',
#   'order': 2,
#   'title': 'Launching GitHub Desktop'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h4',
#   'order': 3,
#   'title': 'Launching Xcode'},
#  {'url': 'https://github.com/sethblack/python-seo-analyzer',
#   'page_title': 'GitHub - sethblack/python-seo-analyzer: An SEO tool that analyzes the structure of a site, crawls the site, count words in the body of the site and warns of any technical SEO issues.',
#   'header': 'h4',
#   'order': 4,
#   'title': 'Launching Visual Studio Code'},
#  {'url': 'https://www.seoradar.com/how-to-use-python-seo/',
#   'page_title': '403 Forbidden',
#   'header': 'h1',
#   'order': 0,
#   'title': '403 Forbidden'},
#  {'url': 'https://rockcontent.com/blog/python-for-seo/',
#   'page_title': 'Python for SEO: A Guide on How to Automate Your Strategy',
#   'header': 'h1',
#   'order': 0,
#   'title': 'How Python can automate your SEO strategy'},
#  {'url': 'https://rockcontent.com/blog/python-for-seo/',
#   'page_title': 'Python for SEO: A Guide on How to Automate Your Strategy',
#   'header': 'h2',
#   'order': 0,
#   'title': 'Subscribe to our blog'},
#  {'url': 'https://rockcontent.com/blog/python-for-seo/',
#   'page_title': 'Python for SEO: A Guide on How to Automate Your Strategy',
#   'header': 'h2',
#   'order': 1,
#   'title': 'Related Posts'},
#  {'url': 'https://rockcontent.com/blog/python-for-seo/',
#   'page_title': 'Python for SEO: A Guide on How to Automate Your Strategy',
#   'header': 'h2',
#   'order': 2,
#   'title': '\n\nThe SEO Recap of 2022 and What’s Ahead in 2023: A Must-Read Retrospective \n'},
#  {'url': 'https://rockcontent.com/blog/python-for-seo/',
#   'page_title': 'Python for SEO: A Guide on How to Automate Your Strategy',
#   'header': 'h2',
#   'order': 3,
#   'title': '\n\nA Retrospective on Consumer Behavior in 2022 and Forecasts for 2023 \n'},
#  {'url': 'https://rockcontent.com/blog/python-for-seo/',
#   'page_title': 'Python for SEO: A Guide on How to Automate Your Strategy',
#   'header': 'h3',
#   'order': 0,
#   'title': 'Machine Learning and Deep Learning'},
#  {'url': 'https://rockcontent.com/blog/python-for-seo/',
#   'page_title': 'Python for SEO: A Guide on How to Automate Your Strategy',
#   'header': 'h3',
#   'order': 1,
#   'title': 'Automation'},
#  {'url': 'https://rockcontent.com/blog/python-for-seo/',
#   'page_title': 'Python for SEO: A Guide on How to Automate Your Strategy',
#   'header': 'h3',
#   'order': 2,
#   'title': 'Libraries and data visualization'},
#  {'url': 'https://rockcontent.com/blog/python-for-seo/',
#   'page_title': 'Python for SEO: A Guide on How to Automate Your Strategy',
#   'header': 'h3',
#   'order': 3,
#   'title': 'Web programming'},
#  {'url': 'https://rockcontent.com/blog/python-for-seo/',
#   'page_title': 'Python for SEO: A Guide on How to Automate Your Strategy',
#   'header': 'h3',
#   'order': 4,
#   'title': 'Integration with other languages'},
#  {'url': 'https://rockcontent.com/blog/python-for-seo/',
#   'page_title': 'Python for SEO: A Guide on How to Automate Your Strategy',
#   'header': 'h3',
#   'order': 5,
#   'title': 'URL Mapping'},
#  {'url': 'https://rockcontent.com/blog/python-for-seo/',
#   'page_title': 'Python for SEO: A Guide on How to Automate Your Strategy',
#   'header': 'h3',
#   'order': 6,
#   'title': 'Analysis of internal links'},
#  {'url': 'https://rockcontent.com/blog/python-for-seo/',
#   'page_title': 'Python for SEO: A Guide on How to Automate Your Strategy',
#   'header': 'h3',
#   'order': 7,
#   'title': 'Keyword search'},
#  {'url': 'https://rockcontent.com/blog/python-for-seo/',
#   'page_title': 'Python for SEO: A Guide on How to Automate Your Strategy',
#   'header': 'h3',
#   'order': 8,
#   'title': 'Image Optimization'},
#  {'url': 'https://rockcontent.com/blog/python-for-seo/',
#   'page_title': 'Python for SEO: A Guide on How to Automate Your Strategy',
#   'header': 'h3',
#   'order': 9,
#   'title': 'Keyword tracking'},
#  {'url': 'https://rockcontent.com/blog/python-for-seo/',
#   'page_title': 'Python for SEO: A Guide on How to Automate Your Strategy',
#   'header': 'h3',
#   'order': 10,
#   'title': 'Performance improvement'},
#  {'url': 'https://rockcontent.com/blog/python-for-seo/',
#   'page_title': 'Python for SEO: A Guide on How to Automate Your Strategy',
#   'header': 'h3',
#   'order': 11,
#   'title': 'Data Extraction'},
#  {'url': 'https://rockcontent.com/blog/python-for-seo/',
#   'page_title': 'Python for SEO: A Guide on How to Automate Your Strategy',
#   'header': 'h3',
#   'order': 12,
#   'title': 'Adding subtitles to images'},
#  {'url': 'https://rockcontent.com/blog/python-for-seo/',
#   'page_title': 'Python for SEO: A Guide on How to Automate Your Strategy',
#   'header': 'h3',
#   'order': 13,
#   'title': 'Image Optimization'},
#  {'url': 'https://rockcontent.com/blog/python-for-seo/',
#   'page_title': 'Python for SEO: A Guide on How to Automate Your Strategy',
#   'header': 'h3',
#   'order': 14,
#   'title': 'SEO Analysis'},
#  {'url': 'https://rockcontent.com/blog/python-for-seo/',
#   'page_title': 'Python for SEO: A Guide on How to Automate Your Strategy',
#   'header': 'h3',
#   'order': 15,
#   'title': 'Search for 404 errors'},
#  {'url': 'https://rockcontent.com/blog/python-for-seo/',
#   'page_title': 'Python for SEO: A Guide on How to Automate Your Strategy',
#   'header': 'h3',
#   'order': 16,
#   'title': 'More in SEO'},
#  {'url': 'https://rockcontent.com/blog/python-for-seo/',
#   'page_title': 'Python for SEO: A Guide on How to Automate Your Strategy',
#   'header': 'h3',
#   'order': 17,
#   'title': '\n\nLocal SEO For Retailers: How To Reach A Ready-To-Buy Audience \n'},
#  {'url': 'https://rockcontent.com/blog/python-for-seo/',
#   'page_title': 'Python for SEO: A Guide on How to Automate Your Strategy',
#   'header': 'h3',
#   'order': 18,
#   'title': '\n\nHow Stage helped the IRKO Group overcome its digital challenges \n'},
#  {'url': 'https://rockcontent.com/blog/python-for-seo/',
#   'page_title': 'Python for SEO: A Guide on How to Automate Your Strategy',
#   'header': 'h3',
#   'order': 19,
#   'title': '\n\nDomain, subdomain or subdirectory: which is better for your website? \n'},
#  {'url': 'https://rockcontent.com/blog/python-for-seo/',
#   'page_title': 'Python for SEO: A Guide on How to Automate Your Strategy',
#   'header': 'h3',
#   'order': 20,
#   'title': 'Want to receive more brilliant content like this for free?'}]

# %%
len(df_master_list)
# Out:
# 283

# %% [markdown]
# # Step 4: Save results to CSV File
#
# Using pandas

# %%
import pandas as pd
   
# Initialise data to lists.

df = pd.DataFrame(df_master_list )
df
# Out:
#                                               url  \
# 0     https://www.jcchouinard.com/python-for-seo/
# 1     https://www.jcchouinard.com/python-for-seo/
# 2     https://www.jcchouinard.com/python-for-seo/
# 3     https://www.jcchouinard.com/python-for-seo/
# 4     https://www.jcchouinard.com/python-for-seo/
# ..                                            ...
# 278  https://rockcontent.com/blog/python-for-seo/
# 279  https://rockcontent.com/blog/python-for-seo/
# 280  https://rockcontent.com/blog/python-for-seo/
# 281  https://rockcontent.com/blog/python-for-seo/
# 282  https://rockcontent.com/blog/python-for-seo/
#
#                                             page_title header  order  \
# 0    Python for SEO: Complete Guide (in 8 Chapters)...     h1      0
# 1    Python for SEO: Complete Guide (in 8 Chapters)...     h2      0
# 2    Python for SEO: Complete Guide (in 8 Chapters)...     h2      1
# 3    Python for SEO: Complete Guide (in 8 Chapters)...     h2      2
# 4    Python for SEO: Complete Guide (in 8 Chapters)...     h2      3
# ..                                                 ...    ...    ...
# 278  Python for SEO: A Guide on How to Automate You...     h3     16
# 279  Python for SEO: A Guide on How to Automate You...     h3     17
# 280  Python for SEO: A Guide on How to Automate You...     h3     18
# 281  Python for SEO: A Guide on How to Automate You...     h3     19
# 282  Python for SEO: A Guide on How to Automate You...     h3     20
#
#                                                  title
# 0       Python for SEO: Complete Guide (in 8 Chapters)
# 1                           Subscribe to my Newsletter
# 2                             Chapter 1: Python Basics
# 3                  Chapter 2: Technical SEO Challenges
# 4                    Chapter 3: Automation With Python
# ..                                                 ...
# 278                                        More in SEO
# 279  \n\nLocal SEO For Retailers: How To Reach A Re...
# 280  \n\nHow Stage helped the IRKO Group overcome i...
# 281  \n\nDomain, subdomain or subdirectory: which i...
# 282  Want to receive more brilliant content like th...
#
# [283 rows x 5 columns]

# %%
df.to_csv("search_sections_for_"+query+".csv", index=False)
